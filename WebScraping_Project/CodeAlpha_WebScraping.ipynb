# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "http://books.toscrape.com/"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

print("HTML Parsed Successfully")
# Out:
# HTML Parsed Successfully

# %%
books = soup.find_all("article", class_="product_pod")

print("Number of books found:", len(books))
# Out:
# Number of books found: 20

# %%
first_book = books[0]

title = first_book.h3.a["title"]

price = first_book.find("p", class_="price_color").text

rating = first_book.find("p")["class"][1]

availability = first_book.find(
    "p", class_="instock availability"
).text.strip()

print("Title:", title)
print("Price:", price)
print("Rating:", rating)
print("Availability:", availability)
# Out:
# Title: A Light in the Attic
# Price: Â£51.77
# Rating: Three
# Availability: In stock

# %%
titles = []
prices = []
ratings = []
availability = []

for book in books:

    title = book.h3.a["title"]

    price = book.find("p", class_="price_color").text

    rating = book.find("p")["class"][1]

    stock = book.find(
        "p", class_="instock availability"
    ).text.strip()

    titles.append(title)
    prices.append(price)
    ratings.append(rating)
    availability.append(stock)

print("Data extracted successfully!")
# Out:
# Data extracted successfully!

# %%
df = pd.DataFrame({
    "Title": titles,
    "Price": prices,
    "Rating": ratings,
    "Availability": availability
})

df.head()
# Out:
#                                    Title    Price Rating Availability
# 0                   A Light in the Attic  Â£51.77  Three     In stock
# 1                     Tipping the Velvet  Â£53.74    One     In stock
# 2                             Soumission  Â£50.10    One     In stock
# 3                          Sharp Objects  Â£47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five     In stock

# %%
df.to_csv("books.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
from google.colab import files

files.download("books.csv")

# %% [markdown]
# # Conclusion
#
# This project demonstrates web scraping using Python and BeautifulSoup. Data including book titles, prices, ratings, and availability was successfully extracted from a public website and converted into a structured dataset.
#
# The extracted data was stored in CSV format, making it suitable for further analysis and visualization.
